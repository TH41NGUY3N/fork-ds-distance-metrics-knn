# %% [markdown]
# # Distance Metrics

# %% [markdown]
# Distance metrics play an essential role in machine learning because they can be used to compare the similarity or dissimilarity of two data points. Commonly used for clustering or classification tasks,  distance-based algorithms assume that points in close proximity are more similar to each other. As the proximity of two points is defined by the distance between them, the choice of metric is of essential importance. Depending on the specific needs of your task, you can choose from a variety of different distance metrics. Most frequently used is the Euclidean, which measures the straight-line distance between two points in Euclidean space. Despite its popularity the Euclidean metric should only be used in lower dimensional space (see curse of dimensionality). For higher dimensional space other approaches like Manhattan distance or cosine similarity are more applicable. In this notebook you find an overview of common distance metrics and how to calculate them in python.

# %%
# Setup
import numpy as np

# %% [markdown]
# # Popular distance metrics

# %% [markdown]
# ## Manhattan Distance

# %% [markdown]
# The Manhattan distance is the sum of absolute differences between the points' coordinates. It is measured along axes at right angles. How the path is taken does not matter, all routes lead to the same distance value.
#
# <p align="center">
#   <img src="images/manhattan1.jpg" alt="drawing" width="200"/>
# </p>

# %% [markdown]
# ### Formula:
#
# $\ Manhattan\: Distance = \sum_{i=1}^n |a_1,_i - a_2,_i|$
#
# $\ Manhattan\: Distance = \sum_{i=1}^n side\: length$

# %% [markdown]
# ### In python code:

# %%
# Example of Manhattan distance
point_1 = (2, 3, 5)
point_2 = (1, -1, 3)

manhattan_distance = 0
for i in range(3):
    manhattan_distance += np.abs(point_1[i] - point_2[i])

manhattan_distance
# Out:
# 7

# %% [markdown]
# ## Euclidean Distance

# %% [markdown]
# The Euclidean distance is defined as the beeline distance between two points. It is calculated from the cartesian coordinates of the points using the pythagorean theorem.
#
# <p align="center">
#   <img src="images/euclidean2.jpg" alt="drawing" width="200"/>
# </p>

# %% [markdown]
# ### Formula:
#
# $\ Euclidean\: Distance = \sqrt{\sum_{i=1}^n |a_1,_i - a_2,_i|^2}$ <br>
# $\ Euclidean\: Distance = \sqrt{\sum_{i=1}^n side\:length^2}$

# %% [markdown]
# ### In python code:

# %%
# Example of Euclidean distance
point_1 = (2, 3, 5)
point_2 = (1, -1, 3)

euclidean_distance = 0
for i in range(3):
    euclidean_distance += (point_1[i] - point_2[i]) ** 2
    print(euclidean_distance)

euclidean = np.sqrt(euclidean_distance)

euclidean
# Out:
# 1
# 17
# 21
# 4.58257569495584

# %% [markdown]
# ## Minkowski distance

# %% [markdown]
# The Minkowski distance is a generalization of the Euclidean distance and can be used to calculate the distance between two points in an n-dimensional space.

# %% [markdown]
# ### Formula:
#
# $\ Minkowski\: Distance = \sqrt[p]{\sum_{i=1}^n |a_1,_i - a_2,_i|^p}$ <br>
# $\ Minkowski\: Distance = \sqrt[p]{\sum_{i=1}^n side\:length^p}$

# %% [markdown]
# ### In python code:

# %%
# Example of Minkowski distance with 3 dimensions
point_1 = (2, 3, 5)
point_2 = (1, -1, 3)
p = 3

minkowski_distance = 0
for i in range(3):
    minkowski_distance += np.abs(point_1[i] - point_2[i]) ** p


minkowski = minkowski_distance ** (1 / p)

minkowski
# Out:
# 4.179339196381232

# %% [markdown]
# # Overview

# %% [markdown]
# ## Distance Metrics Formulas
#
#
# **Manhattan Distance is the sum of all side lengths to the first power:**
#
# $\ Manhattan\: Distance = \sum_{i=1}^n |a_1,_i - a_2,_i|$
#
# $\ Manhattan\: Distance = \sum_{i=1}^n side\: length$
#
# **Euclidean Distance is the square root of the sum of all side lengths to the second power:**
#
# $\ Euclidean\: Distance = \sqrt{\sum_{i=1}^n |a_1,_i - a_2,_i|^2}$ <br>
# $\ Euclidean\: Distance = \sqrt{\sum_{i=1}^n side\:length^2}$
#
# **Minkowski Distance with p = 3 would be the cube root of the sum of all side lengths to the third power:**
#
# $\ Minkowski\: Distance = \sqrt[3]{\sum_{i=1}^n |a_1,_i - a_2,_i|^3}$ <br>
# $\ Minkowski\: Distance = \sqrt[3]{\sum_{i=1}^n side\:length^3}$
#
# **Minkowski Distance with p = 5:**
#
#
# $\ Minkowski\: Distance = \sqrt[5]{\sum_{i=1}^n |a_1,_i - a_2,_i|^5}$ <br>
# $\ Minkowski\: Distance = \sqrt[5]{\sum_{i=1}^n side\:length^5}$

# %% [markdown]
# These exercises are foundational for Machine Learning! When algorithms (like K-Nearest Neighbors) try to find patterns, they literally calculate how "close" data points are to each other.
#
# The beauty of this exercise is that you only need to write **one single formula** to solve for Manhattan, Euclidean, and Minkowski distances.
#
# Here is how to understand the math, followed by the exact code you need to complete your Jupyter Notebook.
#
# ### The "Master Key" (Minkowski Distance)
# The notebook teaches you three different distances, but **Minkowski** is actually the master key. It is a generalized formula that contains the other two inside of it.
#
# Here is the generalized Minkowski formula, where $c$ (sometimes written as $p$) is the "norm":
# $$Distance = \left( \sum_{i=1}^n |a_{1,i} - a_{2,i}|^c \right)^{\frac{1}{c}}$$
#
# *   If you set **c = 1**, the exponents disappear, and this becomes the **Manhattan Distance** (grid-like movement, like driving city blocks).
# *   If you set **c = 2**, the formula naturally becomes the Pythagorean theorem, which is the **Euclidean Distance** (a straight line, as the crow flies).
# *   If you set **c = 3.5**, it's just a higher-order Minkowski distance!
#
# ### 1. The `distance()` Function
# Here is the complete, working code for your `distance()` function. It uses a loop to iterate through the dimensions, calculates the absolute difference using `np.abs()`, raises it to the power of `c`, and finally takes the `c`-th root at the end using `np.power()`.
#
# ```python
# import numpy as np
#
# def distance(pt1, pt2, c=2, verbose=True):
#     # 1. Handle the verbosity (printing the metric being used)
#     if verbose:
#         if c == 1:
#             print("Measurement: Manhattan distance")
#         elif c == 2:
#             print("Measurement: Euclidean distance")
#         else:
#             print(f"Measurement: Minkowski distance (norm {c})")
#
#     # 2. Calculate the Minkowski distance
#     dist_sum = 0
#     for i in range(len(pt1)):
#         # Absolute difference between coordinates, raised to the power of c
#         dist_sum += np.abs(pt1[i] - pt2[i]) ** c
#
#     # 3. Take the c-th root of the final sum
#     final_distance = np.power(dist_sum, 1/c)
#
#     return final_distance
# ```
#
# ### 2. Solving the Test Cases
# Now that your function is built, you can use it to pass the three `check_distance` validation tests at the bottom of your notebook.
#
# **Test 1: Euclidean Distance (6-Dimensional Space)**
# Since Euclidean is the default (`c=2`), we don't even need to pass the `c` argument!
# ```python
# pt1 = (-2, -5.8, 14, 15, 7, 9)
# pt2 = (3, -9.2, -33, -21, 7, 9)
#
# # We can set verbose=False to keep the output clean during testing
# your_euclidean_distance = distance(pt1, pt2, verbose=False)
#
# if your_euclidean_distance is not None:
#     check_distance(your_euclidean_distance, 59.51100738518883)
# ```
#
# **Test 2: Manhattan Distance (9-Dimensional Space)**
# For Manhattan, we just set `c=1`.
# ```python
# pt1 = [0, 0, 0, 7, 16, 2, 0, 1, 12]
# pt2 = [21, -1, 35, 17, 14, 73, -22, 33, 3]
#
# your_manhattan_distance = distance(pt1, pt2, c=1, verbose=False)
#
# if your_manhattan_distance is not None:
#     check_distance(your_manhattan_distance, 203.0)
# ```
#
# **Test 3: Minkowski Distance (norm of 3.5)**
# For the generalized Minkowski, we plug the exact norm into `c`.
# ```python
# pt1 = (-32, 47, 223.4)
# pt2 = (883, 34, 199.5)
#
# your_minkowski_distance = distance(pt1, pt2, c=3.5, verbose=False)
#
# if your_minkowski_distance is not None:
#     check_distance(your_minkowski_distance, 915.0008423267521)
# ```
#
# Want to explore how this exact math is used in the real world to build clustering models or K-Nearest Neighbors algorithms?
